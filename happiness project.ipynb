# %% [markdown]
# #           Happiness dataset

# %% [markdown]
# data description

# %% [markdown]
# The task is to train the world happiness dataset and predict the happiness score

# %% [markdown]
# # Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
#loading dataset

# %%
df=pd.read_csv("C:/Users/Lenovo/Downloads/happiness.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.describe()#statistical analysis
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#checking null values

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# There is no null values in the dataset

# %%
df=df[['Country','Region','Standard Error', 'Economy (GDP per Capita)', 'Family','Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual','Happiness Score']]

# %%
sns.heatmap(df.isnull())

# %%
df['Happiness Score'].hist()

# %%
from sklearn.preprocessing import LabelEncoder
for col in df.columns:
    if df[col].dtypes=='object':
        le=LabelEncoder()
        df[col]=le.fit_transform(df[col])
# Out:
# <ipython-input-62-071b9d2f4d9b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=le.fit_transform(df[col])

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()

# %%
corr=df.corr()
plt.figure(figsize=[22,12])
sns.heatmap(corr,annot=True)
plt.title("Corelation Matrix")
plt.show()#example of multivariate analysis

# %%
corr['Happiness Score'].sort_values
# Out:
# <bound method Series.sort_values of Country                          0.083380
# Region                          -0.176791
# Standard Error                  -0.177254
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64>

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# Happiness Score                  0.097769
# dtype: float64

# %%
df.plot(kind='density',subplots=True,layout=(6,11),sharex=False,fontsize=1,figsize=(18,12))
plt.show()

# %%
for i in df.columns:
    sns.boxplot(df[i])
    plt.show()

# %%
#due to outlier present in the dataset,we remove it by using zscore

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.23877001, 1.30025593, 0.80592569, ..., 0.47103971, 0.75825809,
#         1.93736005],
#        [0.44946522, 1.30025593, 0.05588945, ..., 1.57585637, 1.09285682,
#         1.91458063],
#        [0.90989302, 1.30025593, 0.8544869 , ..., 0.8242928 , 0.71233526,
#         1.88479215],
#        ...,
#        [1.26069514, 0.37544095, 0.13253425, ..., 1.85689094, 3.20843049,
#         2.0761992 ],
#        [1.26069514, 0.96511655, 2.26396166, ..., 0.31694987, 0.48198451,
#         2.1646885 ],
#        [1.37032081, 0.96511655, 1.13418227, ..., 0.5581534 , 0.96361241,
#         2.22251319]])

# %%
df=df[(z<3).all(axis=1)]
df
# Out:
#      Country  Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0        135       9         0.03411                   1.39651  1.34951
# 1         58       9         0.04884                   1.30232  1.40223
# 2         37       9         0.03328                   1.32548  1.36058
# 3        105       9         0.03880                   1.45900  1.33095
# 4         24       5         0.03553                   1.32629  1.32261
# ..       ...     ...             ...                       ...      ...
# 150       66       8         0.05141                   0.46534  0.77115
# 151       20       8         0.04324                   0.25812  0.85188
# 152        0       7         0.03084                   0.31982  0.30285
# 154       13       8         0.03656                   0.28665  0.35386
# 156       21       8         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
x=df.drop('Happiness Score',axis=1)
y=df['Happiness Score']

# %%
from sklearn.preprocessing import power_transform
df_new=power_transform(x)
df_new=pd.DataFrame(df_new,columns=x.columns)

# %%
x=df_new

# %% [markdown]
# skewness is removed

# %%
x
# Out:
#       Country    Region  Standard Error  Economy (GDP per Capita)    Family  \
# 0    1.190155  1.234514       -0.950337                  1.492454  1.658880
# 1   -0.300487  1.234514        0.378562                  1.194067  2.009125
# 2   -0.802057  1.234514       -1.041401                  1.266612  1.730785
# 3    0.652787  1.234514       -0.471124                  1.695302  1.540248
# 4   -1.157249  0.055028       -0.799032                  1.269159  1.487718
# ..        ...       ...             ...                       ...       ...
# 144 -0.124925  0.955280        0.563000                 -1.052662 -1.047195
# 145 -1.277525  0.955280       -0.068119                 -1.490349 -0.778550
# 146 -2.105378  0.666736       -1.320810                 -1.365216 -2.087389
# 147 -1.507282  0.955280       -0.692726                 -1.433041 -2.010443
# 148 -1.246831  0.955280        2.178766                 -1.938747 -1.906410
#
# ...

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
for i in x.columns:
    sns.distplot(df[i])
    plt.show()

# %%
#finding best random_state

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
lr=LinearRegression()
maxacc=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    acc=r2_score(y_test,y_pred)
    if acc > maxacc:
        maxacc=acc
        maxrs=i
print("best accuracy is",maxacc,"on random_state",maxrs)
# Out:
# best accuracy is 0.99796806472993 on random_state 37

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=37)

# %%
#we are not doing scaling due to all the data are in same range

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.99796806472993
# 0.0031047620791610814
# 0.0473926081055439

# %%
from sklearn.linear_model import Lasso
ls=Lasso(alpha=0.001)
ls.fit(x_train,y_train)
y_pred=ls.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9979887450853899
# 0.003073162852374108
# 0.04727217768498516

# %%
from sklearn.linear_model import Ridge
rg=Ridge(alpha=0.001)
rg.fit(x_train,y_train)
y_pred=rg.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9979681283703971
# 0.003104664837624116
# 0.04739290067003539

# %%
from sklearn.linear_model import ElasticNet
es=ElasticNet(alpha=0.001)
es.fit(x_train,y_train)
y_pred=es.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9979819534688791
# 0.003083540325372231
# 0.04735034410033116

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.7173884068744973
# 0.4318256444444444
# 0.5031555555555555

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
y_pred=svr.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9488617543674823
# 0.07813835813244112
# 0.2057953131386751

# %%
from sklearn.ensemble import AdaBoostRegressor
ad=AdaBoostRegressor(random_state=37,n_estimators=100)
ad.fit(x_train,y_train)
y_pred=ad.predict(x_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.8873349728426532

# %%
from sklearn.ensemble import GradientBoostingRegressor
gd=GradientBoostingRegressor(learning_rate=0.1,n_estimators=100)
gd.fit(x_train,y_train)
y_pred=gd.predict(x_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.95027682163268

# %%
#we are getting highest accuracy in logisticregression of 99%,but it can be due to overfitting

# %%
from sklearn.model_selection import cross_val_score
acc=cross_val_score(lr,x,y,cv=5)
acc.mean()
# Out:
# 0.8572275229667102

# %%
from sklearn.model_selection import cross_val_score
acc=cross_val_score(ls,x,y,cv=5)
acc.mean()
# Out:
# 0.8571053346465621

# %%
from sklearn.model_selection import cross_val_score
acc=cross_val_score(rg,x,y,cv=5)
acc.mean()
# Out:
# 0.8572289996157778

# %%
from sklearn.model_selection import cross_val_score
acc=cross_val_score(es,x,y,cv=5)
acc.mean()
# Out:
# 0.8572703697838755

# %%
from sklearn.model_selection import cross_val_score
acc=cross_val_score(ad,x,y,cv=5)
acc.mean()
# Out:
# -6.181611619317666

# %%
from sklearn.model_selection import cross_val_score
acc=cross_val_score(dt,x,y,cv=5)
acc.mean()
# Out:
# -8.30035195782127

# %%
from sklearn.model_selection import cross_val_score
acc=cross_val_score(svr,x,y,cv=5)
acc.mean()
# Out:
# -3.429765875848827

# %%
from sklearn.model_selection import cross_val_score
acc=cross_val_score(gd,x,y,cv=5)
acc.mean()
# Out:
# -2.5807802758823923

# %%
#minimum difference is the accuracy,so ElasticNet is the best model, we use for this dataset.so we have to make it hyperparameter_tuning

# %%
from sklearn.model_selection import GridSearchCV
ratio=np.arange(0,1,0.1)
alpha=[1e-5,1e-4,1e-4,1e-3,1e-1,0,0.1,1.0,100]
parameter={'l1_ratio':ratio,'alpha':alpha}
gscv=GridSearchCV(ElasticNet(),parameter,cv=5)
gscv.fit(x_train,y_train)
# Out:
# C:\Users\Lenovo\anacon\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2832332834428915, tolerance: 0.008888567096385544
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anacon\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1892998317845838, tolerance: 0.009581776279518074
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Lenovo\anacon\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2743055105700493, tolerance: 0.009179074626506025
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
gscv.best_params_
# Out:
# {'alpha': 0.001, 'l1_ratio': 0.9}

# %%
gscv.best_score_
# Out:
# 0.9897969745686421

# %%
gscv.best_estimator_
# Out:
# ElasticNet(alpha=0.001, l1_ratio=0.9)

# %%
gscv_pred=gscv.best_estimator_.predict(x_test)

# %%
r2_score(y_test,gscv_pred)
# Out:
# 0.9979874667262263

# %%
import joblib
joblib.dump(gscv.best_estimator_,"happinessmodel.obj")
# Out:
# ['happinessmodel.obj']
